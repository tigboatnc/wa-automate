# %% [markdown]
# `/clients/YIJ3bLzUXlubsxnDPnDR/projects/BOuyALnDYmDHSBW7kAZm/wa-queue`|

# %%
# Firebase Imports 
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import threading
from google.api_core.datetime_helpers import DatetimeWithNanoseconds

# Selenium Imports 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

import copy
from urllib.parse import urlparse
import numpy as np
import pandas as pd
import re 
from pathlib import Path
import os
import time
from datetime import date
from datetime import timedelta
from datetime import datetime
import dateutil.parser as parser

import time

today = date.today()
cwd = os.getcwd()

# %%
project_id = 'tpc-dev-5330f'
# Use the application default credentials
cred = firebase_admin.credentials.Certificate('./secret/tpc-dev-5330f-firebase-adminsdk-2p698-e13719db26.json')

firebase_admin.initialize_app(cred, {
  'projectId': project_id,
})

db = firestore.client()

# %%
doc_ref = db.collection(u'clients').document(u'YIJ3bLzUXlubsxnDPnDR').collection(u'projects').document(u'BOuyALnDYmDHSBW7kAZm').collection('wa-queue')

# %%
# Create an Event for notifying main thread.
callback_done = threading.Event()
# MAIN VARIABLE : Clean after use 
process_queue = []

# Create a callback on_snapshot function to capture changes
def on_snapshot(col_snapshot, changes, read_time):
    for doc in col_snapshot:
#         print(f'{doc.id}')
        process_queue.append(doc.id)
    callback_done.set()
    

col_query = db.collection(u'clients').document(u'YIJ3bLzUXlubsxnDPnDR').collection(u'projects').document(u'BOuyALnDYmDHSBW7kAZm').collection('wa-queue').where(u'processed', u'==', False)

# Watch the collection query
query_watch = col_query.on_snapshot(on_snapshot)

# %%
# RUN WA AUTOMATION HERE --------------


# START WHATSAPP SEND 

# Starting the selenium webserver and getting whatsapp 
userprofile = 'samarth'
options = webdriver.ChromeOptions()
options.add_argument(f"user-data-dir={cwd}/."+userprofile+"UserProfile")
driver = webdriver.Chrome(ChromeDriverManager().install() , options=options)
driver.get("https://web.whatsapp.com/")


# Default getter functions 
def F_SEARCH_2(driverVar,contact_number):

    driverVar.find_element(By.CSS_SELECTOR, "body").send_keys(Keys.CONTROL + Keys.COMMAND + '//')
    time.sleep(1)


    FORM_HEADER_CLASS = '_1Jn3C' # Label Class
    FORM_CLASS = '_13NKt copyable-text selectable-text'

    formHeadingClassList = driverVar.find_elements(By.XPATH,f"//label[@class='{FORM_HEADER_CLASS}']")

    print(len(formHeadingClassList))


    if len(formHeadingClassList)==1:
        formHeadingClass = formHeadingClassList[0]
        formElementsList = formHeadingClass.find_elements(By.XPATH,f".//div[@class='{FORM_CLASS}']")

        print(len(formElementsList))

        if len(formElementsList)>0:
            formElement = formElementsList[0]
            formElement.click();
            formElement.clear();
            formElement.send_keys(f'{contact_number}')
            time.sleep(4)
            formElement.send_keys(Keys.RETURN)   

            
def F_SINGLE_SEND(driverVar,text_message):
    CHAT_HEADER_CLASS = '_1UWac _1LbR4'
    ALT_CHAT_HEADER_CLASS = '_1UWac _1LbR4 focused'
    CHAT_CLASS = '_13NKt copyable-text selectable-text'

    print('Trying Unfocussed')
    chatHeadingClassList = driverVar.find_elements(By.XPATH,f"//div[@class='{CHAT_HEADER_CLASS}']")
    if len(chatHeadingClassList)==0:
        print('Unfocussed failed, trying focussed;')
        chatHeadingClassList = driverVar.find_elements(By.XPATH,f"//div[@class='{ALT_CHAT_HEADER_CLASS}']")
    print(f'Length of Chat Header Div => {len(chatHeadingClassList)}')

    if len(chatHeadingClassList)==1:
        chatHeadingClass = chatHeadingClassList[0]
        chatElementsList = chatHeadingClass.find_elements(By.XPATH,f".//div[@class='{CHAT_CLASS}']")
        print(len(chatElementsList))
        if len(chatElementsList)>0:
            chatElement = chatElementsList[0]
            chatElement.click();
            time.sleep(1)
            chatElement.clear();
            chatElement.send_keys(f'{text_message}')
            time.sleep(2)
            chatElement.send_keys(Keys.RETURN)
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 97.0.4692
# [WDM] - Get LATEST driver version for 97.0.4692
# [WDM] - Get LATEST driver version for 97.0.4692
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/97.0.4692.71/chromedriver_mac64.zip
# [WDM] - Driver has been saved in cache [/Users/flipflops/.wdm/drivers/chromedriver/mac64/97.0.4692.71]
# /usr/local/Caskroom/miniconda/base/envs/tpc-wa/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   # Remove the CWD from sys.path while we load stuff.

# %%
while(True):
    
    
    print('Status - Sleep---------------')
    time.sleep(10)


    print('STATUS : Checking Queue')
    process_queue_clean = list(set(process_queue))


    if len(process_queue_clean)>0:  
        print(f'FOUND {len(process_queue_clean)} jobs')

        print('STATUS : Running Job')
        for TASK_ID in process_queue_clean:
            task_doc_ref = db.collection(u'clients').document(u'YIJ3bLzUXlubsxnDPnDR').collection(u'projects').document(u'BOuyALnDYmDHSBW7kAZm').collection('wa-queue').document(TASK_ID)
            task_doc = task_doc_ref.get()
            TASKDATA = task_doc.to_dict()
            TASK_PHONE = TASKDATA['contactPhone']
            TASK_MESSAGE = TASKDATA['messageContent'] 
            TASK_GUEST = TASKDATA['guestId'] 
            
            TASKDATA['processed'] = True
            task_doc_ref = db.collection(u'clients').document(u'YIJ3bLzUXlubsxnDPnDR').collection(u'projects').document(u'BOuyALnDYmDHSBW7kAZm').collection('wa-queue').document(TASK_ID).delete()
            
            
            

            print('SEND TO : ', TASK_PHONE)
            print('MESSAGE : ',TASK_MESSAGE)


            F_SEARCH_2(driver,TASK_PHONE)
            F_SINGLE_SEND(driver,TASK_MESSAGE)
            
            
#           Adding to database 
            doc_guest_ref = db.collection(u'clients').document(u'YIJ3bLzUXlubsxnDPnDR').collection(u'projects').document(u'BOuyALnDYmDHSBW7kAZm').collection('guests').document(u'BOuyALnDYmDHSBW7kAZm').collection(u'guest-data').document(TASK_GUEST)
            doc_guest = doc_guest_ref.get()
            TASKDATA_GUEST = doc_guest.to_dict()
            
            


            if 'conversation' in TASKDATA_GUEST:
                pass
            else:
                TASKDATA_GUEST['conversation'] = [] 


            # 3. add conversation to db 
            TASKDATA_GUEST['conversation'].append(
            {
               'message' : TASK_MESSAGE,
                'timestamp' : datetime.now(),
                'context' : 'wa-send',
                'status' : 'sent'
            })
            
            doc_guest_ref = db.collection(u'clients').document(u'YIJ3bLzUXlubsxnDPnDR').collection(u'projects').document(u'BOuyALnDYmDHSBW7kAZm').collection('guests').document(u'BOuyALnDYmDHSBW7kAZm').collection(u'guest-data').document(TASK_GUEST).set(TASKDATA_GUEST)




            
        process_queue = []
# Out:
# Status - Sleep---------------
# STATUS : Checking Queue
# FOUND 1 jobs
# STATUS : Running Job
# SEND TO :  9711096888
# MESSAGE :  hi aman
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# FOUND 3 jobs
# STATUS : Running Job
# SEND TO :  918218165149
# MESSAGE :  how are you doing
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# SEND TO :  918218165149
# MESSAGE :  how are you
#
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# SEND TO :  918218165149
# MESSAGE :  hi shivam
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# FOUND 1 jobs
# STATUS : Running Job
# SEND TO :  9711096888
# MESSAGE :  this is a test demo
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# FOUND 1 jobs
# STATUS : Running Job
# SEND TO :  918218165149
# MESSAGE :  this asofbasf asljofb asf sdg
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# FOUND 1 jobs
# STATUS : Running Job
# SEND TO :  9953674770
# MESSAGE :  ho help me
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# Status - Sleep---------------
# STATUS : Checking Queue
# FOUND 3 jobs
# STATUS : Running Job
# SEND TO :  2408851895
# MESSAGE :  this is also a message
#
# 1
# 1
# Trying Unfocussed
# Length of Chat Header Div => 1
# 1
# SEND TO :  9711096888
# MESSAGE :  no sire
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# SEND TO :  918218165149
# MESSAGE :  this is also a test
# 1
# 1
# Trying Unfocussed
# Unfocussed failed, trying focussed;
# Length of Chat Header Div => 1
# 1
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------
# STATUS : Checking Queue
# Status - Sleep---------------

# %%
# 1.  -------------------------- Get current task list --------------------------
process_queue_clean = list(set(process_queue))
process_queue_clean

# All the tasks to be carried out 
TASKLIST = []
for task_id in process_queue_clean:
    task_doc_ref = db.collection(u'clients').document(u'YIJ3bLzUXlubsxnDPnDR').collection(u'projects').document(u'BOuyALnDYmDHSBW7kAZm').collection('wa-queue').document(task_id)
    task_doc = task_doc_ref.get()
    TASKDATA = task_doc.to_dict()
    TASKLIST.append(TASKDATA)

# 1.1 -------------------------- Process the task list --------------------------
# Add python readable date to the task list 
for task in TASKLIST:
    task['pythonDate'] = datetime.fromtimestamp(task['createdAt'].timestamp())
    
# Sorting list based on which message is supposed to be sent earlier 
TASKLIST.sort(key=lambda item:item['createdAt'])
# Out:
# S4xKJOpJu716uBtr8Nbl
# 616kbBNGrDl7169X52bP
# IaV4tQWPE0EVnSxrVpgy
# 2oQ3beM0knZSct2Kr2Bg
# IhZSMo6x0OPV9MMQsulg
# 7n7cFBCHQdrUNyEBa9z8
# PIeSP2fqclO8leuMLGam
# UfB5uIU1KuMYPFrBzucz

# %%
# Out:
# {'attachment': {'name': '',
#   'type': '',
#   'url': '',
#   'createdAt': DatetimeWithNanoseconds(2022, 2, 6, 17, 22, 24, 863000, tzinfo=datetime.timezone.utc)},
#  'createdAt': DatetimeWithNanoseconds(2022, 2, 6, 17, 22, 48, 883000, tzinfo=datetime.timezone.utc),
#  'type': 'send',
#  'guestId': 'BatcsRBqhRHyT8JGX4iT',
#  'processed': False,
#  'clientId': 'YIJ3bLzUXlubsxnDPnDR',
#  'contactPhone': '918218165149',
#  'messageContent': 'bbbb',
#  'pythonDate': datetime.datetime(2022, 2, 6, 12, 22, 48, 883000)}

# %%
# 2. -------------------------- Process task list --------------------------

for task in TASKLIST:
    print(task)
    print('Running Task : SEND')
    target = task['contactPhone']
    contect = task['messageContent']
# Out:
# {'contactPhone': '918218165149', 'messageContent': '🤣', 'createdAt': DatetimeWithNanoseconds(2022, 2, 2, 18, 57, 52, 179000, tzinfo=datetime.timezone.utc), 'type': 'send', 'attachment': {'url': '', 'createdAt': DatetimeWithNanoseconds(2022, 2, 2, 18, 27, 21, 316000, tzinfo=datetime.timezone.utc), 'name': '', 'type': ''}, 'processed': False, 'clientId': 'YIJ3bLzUXlubsxnDPnDR', 'guestId': 'BatcsRBqhRHyT8JGX4iT', 'pythonDate': datetime.datetime(2022, 2, 2, 13, 57, 52, 179000)}
# {'createdAt': DatetimeWithNanoseconds(2022, 2, 2, 18, 59, 36, 124000, tzinfo=datetime.timezone.utc), 'messageContent': '', 'attachment': {'createdAt': DatetimeWithNanoseconds(2022, 2, 2, 18, 27, 21, 316000, tzinfo=datetime.timezone.utc), 'url': '', 'type': '', 'name': ''}, 'contactPhone': '918218165149', 'processed': False, 'guestId': 'BatcsRBqhRHyT8JGX4iT', 'clientId': 'YIJ3bLzUXlubsxnDPnDR', 'type': 'send', 'pythonDate': datetime.datetime(2022, 2, 2, 13, 59, 36, 124000)}
# {'processed': False, 'attachment': {'type': '', 'url': '', 'createdAt': DatetimeWithNanoseconds(2022, 2, 3, 10, 36, 2, 876000, tzinfo=datetime.timezone.utc), 'name': ''}, 'clientId': 'YIJ3bLzUXlubsxnDPnDR', 'contactPhone': '9711096888', 'type': 'send', 'guestId': 'L813do8grnQOq3bapqnh', 'messageContent': '  bbbbbbbbbbbbbb', 'createdAt': DatetimeWithNanoseconds(2022, 2, 3, 10, 39, 48, 681000, tzinfo=datetime.timezone.utc), 'pythonDate': datetime.datetime(2022, 2, 3, 5, 39, 48, 681000)}
# {'type': 'send', 'createdAt': DatetimeWithNanoseconds(2022, 2, 3, 10, 39, 49, 901000, tzinfo=datetime.timezone.utc), 'messageContent': '', 'clientId': 'YIJ3bLzUXlubsxnDPnDR', 'attachment': {'url': '', 'createdAt': DatetimeWithNanoseconds(2022, 2, 3, 10, 36, 2, 876000, tzinfo=datetime.timezone.utc), 'name': '', 'type': ''}, 'guestId': 'L813do8grnQOq3bapqnh', 'processed': False, 'contactPhone': '9711096888', 'pythonDate': datetime.datetime(2022, 2, 3, 5, 39, 49, 901000)}
# {'messageContent': 'XX', 'createdAt': DatetimeWithNanoseconds(2022, 2, 4, 11, 25, 49, 69000, tzinfo=datetime.timezone.utc), 'clientId': 'YIJ3bLzUXlubsxnDPnDR', 'contactPhone': '918218165149', 'type': 'send', 'guestId': 'BatcsRBqhRHyT8JGX4iT', 'attachment': {'createdAt': DatetimeWithNanoseconds(2022, 2, 4, 11, 24, 52, 778000, tzinfo=datetime.timezone.utc), 'name': '', 'url': '', 'type': ''}, 'processed': False, 'pythonDate': datetime.datetime(2022, 2, 4, 6, 25, 49, 69000)}
# {'guestId': 'BatcsRBqhRHyT8JGX4iT', 'messageContent': 'bbb', 'contactPhone': '918218165149', 'type': 'send', 'attachment': {'type': '', 'createdAt': DatetimeWithNanoseconds(2022, 2, 6, 17, 22, 24, 863000, tzinfo=datetime.timezone.utc), 'url': '', 'name': ''}, 'processed': False, 'createdAt': DatetimeWithNanoseconds(2022, 2, 6, 17, 22, 44, 117000, tzinfo=datetime.timezone.utc), 'clientId': 'YIJ3bLzUXlubsxnDPnDR', 'pythonDate': datetime.datetime(2022, 2, 6, 12, 22, 44, 117000)}
# {'clientId': 'YIJ3bLzUXlubsxnDPnDR', 'createdAt': DatetimeWithNanoseconds(2022, 2, 6, 17, 22, 45, 217000, tzinfo=datetime.timezone.utc), 'processed': False, 'contactPhone': '918218165149', 'guestId': 'BatcsRBqhRHyT8JGX4iT', 'attachment': {'url': '', 'type': '', 'createdAt': DatetimeWithNanoseconds(2022, 2, 6, 17, 22, 24, 863000, tzinfo=datetime.timezone.utc), 'name': ''}, 'messageContent': '', 'type': 'send', 'pythonDate': datetime.datetime(2022, 2, 6, 12, 22, 45, 217000)}
# {'attachment': {'name': '', 'type': '', 'url': '', 'createdAt': DatetimeWithNanoseconds(2022, 2, 6, 17, 22, 24, 863000, tzinfo=datetime.timezone.utc)}, 'createdAt': DatetimeWithNanoseconds(2022, 2, 6, 17, 22, 48, 883000, tzinfo=datetime.timezone.utc), 'type': 'send', 'guestId': 'BatcsRBqhRHyT8JGX4iT', 'processed': False, 'clientId': 'YIJ3bLzUXlubsxnDPnDR', 'contactPhone': '918218165149', 'messageContent': 'bbbb', 'pythonDate': datetime.datetime(2022, 2, 6, 12, 22, 48, 883000)}

# %%
# 3. -------------------------- Reflect tasks on wa-queue --------------------------

# %%
# 4. -------------------------- Add conversations to respective guests --------------------------
